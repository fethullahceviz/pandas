# %%
import pandas as pd
# Dataset link: https://www.kaggle.com/jsphyg/weather-dataset-rattle-package

# %% [markdown]
# #### 1.Read the dataset as a dataframe. Create a copy of your dataframe. Solve the rest of the questions using this dataframe copy.

# %%
data = pd.read_csv('weatherAUS.csv')
df = data.copy()
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2         No
# 3       1017.6       1012.8       NaN       NaN     18.1     26.5         No
# 4       1010.8       1006.0       7.0       8.0     17.8     29.7         No
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
# 3            No
# 4            No
#
# [5 rows x 23 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### 2.Find out the describe and info attributes of the dataframe. Analyze these information and create a short write-up according to your findings.

# %%
print(df.info())
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB
# None
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# 25%        4.800000      31.000000       7.000000      13.000000
# 50%        8.400000      39.000000      13.000000      19.000000
# 75%       10.600000      48.000000      19.000000      24.000000
# max       14.500000     135.000000     130.000000      87.000000
#
#          Humidity9am    Humidity3pm   Pressure9am    Pressure3pm  \
# count  142806.000000  140953.000000  130395.00000  130432.000000
# mean       68.880831      51.539116    1017.64994    1015.255889
# std        19.029164      20.795902       7.10653       7.037414
# min         0.000000       0.000000     980.50000     977.100000
# 25%        57.000000      37.000000    1012.90000    1010.400000
# 50%        70.000000      52.000000    1017.60000    1015.200000
# 75%        83.000000      66.000000    1022.40000    1020.000000
# max       100.000000     100.000000    1041.00000    1039.600000
#
#            Cloud9am      Cloud3pm        Temp9am       Temp3pm
# count  89572.000000  86102.000000  143693.000000  141851.00000
# mean       4.447461      4.509930      16.990631      21.68339
# std        2.887159      2.720357       6.488753       6.93665
# min        0.000000      0.000000      -7.200000      -5.40000
# 25%        1.000000      2.000000      12.300000      16.60000
# 50%        5.000000      5.000000      16.700000      21.10000
# 75%        7.000000      7.000000      21.600000      26.40000
# max        9.000000      9.000000      40.200000      46.70000

# %%
# Weather information about 49 cities in Austria in this data.The data consists of 23 columns and 145460 rows.

# %% [markdown]
# ---

# %% [markdown]
# ### 3.Find out the shape and size info of the dataset.

# %%
print("size  :", df.size)
print("shape :", df.shape)
# Out:
# size  : 3345580
# shape : (145460, 23)

# %% [markdown]
# ---

# %% [markdown]
# #### 4.Find out the types values of the columns and save the result as a dataframe.

# %%
data_typ = pd.DataFrame(df.dtypes, columns=["data types"])
data_typ
# Out:
#               data types
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object

# %% [markdown]
# ---

# %% [markdown]
# #### 5.Find out the non-null counts of the columns and save the result as a dataframe.

# %%
nonNull = pd.DataFrame(df.notnull().sum(), columns=["non-null"])
nonNull
# Out:
#                non-null
# Date             145460
# Location         145460
# MinTemp          143975
# MaxTemp          144199
# Rainfall         142199
# Evaporation       82670
# Sunshine          75625
# WindGustDir      135134
# WindGustSpeed    135197
# WindDir9am       134894
# WindDir3pm       141232
# WindSpeed9am     143693
# WindSpeed3pm     142398
# Humidity9am      142806
# Humidity3pm      140953
# Pressure9am      130395
# Pressure3pm      130432
# Cloud9am          89572
# Cloud3pm          86102
# Temp9am          143693
# Temp3pm          141851
# RainToday        142199
# RainTomorrow     142193

# %% [markdown]
# ---

# %% [markdown]
# #### 6.Find out the null counts of the columns and save the result as a dataframe.

# %%
null = pd.DataFrame(df.isnull().sum(), columns=["null"])
null
# Out:
#                 null
# Date               0
# Location           0
# MinTemp         1485
# MaxTemp         1261
# Rainfall        3261
# Evaporation    62790
# Sunshine       69835
# WindGustDir    10326
# WindGustSpeed  10263
# WindDir9am     10566
# WindDir3pm      4228
# WindSpeed9am    1767
# WindSpeed3pm    3062
# Humidity9am     2654
# Humidity3pm     4507
# Pressure9am    15065
# Pressure3pm    15028
# Cloud9am       55888
# Cloud3pm       59358
# Temp9am         1767
# Temp3pm         3609
# RainToday       3261
# RainTomorrow    3267

# %% [markdown]
# ---

# %% [markdown]
# #### 7. Find out the unique counts of the columns and save the result as a dataframe.

# %%
unique = pd.DataFrame(df.nunique(), columns=['nunique'])
unique
# Out:
#                nunique
# Date              3436
# Location            49
# MinTemp            389
# MaxTemp            505
# Rainfall           681
# Evaporation        358
# Sunshine           145
# WindGustDir         16
# WindGustSpeed       67
# WindDir9am          16
# WindDir3pm          16
# WindSpeed9am        43
# WindSpeed3pm        44
# Humidity9am        101
# Humidity3pm        101
# Pressure9am        546
# Pressure3pm        549
# Cloud9am            10
# Cloud3pm            10
# Temp9am            441
# Temp3pm            502
# RainToday            2
# RainTomorrow         2

# %% [markdown]
# ---

# %% [markdown]
# #### 8.Merge the dataframes you created in questions 4-5-6-7. Expected output: example result

# %%
columns     = pd.DataFrame(df.columns, columns=["columns"]) # columns dataframe
columns.reset_index(drop=True, inplace=True)
data_typ.reset_index(drop=True, inplace=True)
null.reset_index(drop=True, inplace=True)
nonNull.reset_index(drop=True, inplace=True)
unique.reset_index(drop=True, inplace=True)
data_frames = [columns, data_typ, null, nonNull, unique]
merge_df    = pd.concat(data_frames, join='outer', axis=1)
merge_df
# Out:
#           columns data types   null  non-null  nunique
# 0            Date     object      0    145460     3436
# 1        Location     object      0    145460       49
# 2         MinTemp    float64   1485    143975      389
# 3         MaxTemp    float64   1261    144199      505
# 4        Rainfall    float64   3261    142199      681
# 5     Evaporation    float64  62790     82670      358
# 6        Sunshine    float64  69835     75625      145
# 7     WindGustDir     object  10326    135134       16
# 8   WindGustSpeed    float64  10263    135197       67
# 9      WindDir9am     object  10566    134894       16
# 10     WindDir3pm     object   4228    141232       16
# 11   WindSpeed9am    float64   1767    143693       43
# 12   WindSpeed3pm    float64   3062    142398       44
# 13    Humidity9am    float64   2654    142806      101
# 14    Humidity3pm    float64   4507    140953      101
# 15    Pressure9am    float64  15065    130395      546
# 16    Pressure3pm    float64  15028    130432      549
# 17       Cloud9am    float64  55888     89572       10
# 18       Cloud3pm    float64  59358     86102       10
# 19        Temp9am    float64   1767    143693      441
# 20        Temp3pm    float64   3609    141851      502
# 21      RainToday     object   3261    142199        2
# 22   RainTomorrow     object   3267    142193        2

# %% [markdown]
# ---

# %% [markdown]
# #### 9. Lowercase all column names.

# %%
df.columns = map(str.lower, df.columns)
#df.columns = df.columns.str.lower()
df.head(2)
# Out:
#          date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
#
#   windgustdir  windgustspeed winddir9am  ... humidity9am  humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
#
#    pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8         No
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3         No
#
#    raintomorrow
# 0            No
# 1            No
#
# [2 rows x 23 columns]

# %% [markdown]
# ---

# %% [markdown]
# #### 10.Change all the No values to NoRain and all the Yes values to Rain in raintoday and raintomorrow columns.

# %%
df.raintoday.replace(['No','Yes'],['NoRain','Rain'], inplace=True)
df.raintomorrow.replace(['No','Yes'],['NoRain','Rain'], inplace=True)
df.loc[:, "raintoday":"raintomorrow"]
# Out:
#        raintoday raintomorrow
# 0         NoRain       NoRain
# 1         NoRain       NoRain
# 2         NoRain       NoRain
# 3         NoRain       NoRain
# 4         NoRain       NoRain
# ...          ...          ...
# 145455    NoRain       NoRain
# 145456    NoRain       NoRain
# 145457    NoRain       NoRain
# 145458    NoRain       NoRain
# 145459    NoRain          NaN
#
# [145460 rows x 2 columns]

# %% [markdown]
# ### 11.Change the data type of "date" (object) column to datetime64 and reformat the date as DD/MM/YYYY.

# %%
df.date = pd.to_datetime(df.date)
df.date = df.date.dt.strftime('%d/%m/%Y')
df.head(3)
# Out:
#          date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0  01/12/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02/12/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03/12/2008   Albury     12.9     25.7       0.0          NaN       NaN
#
#   windgustdir  windgustspeed winddir9am  ... humidity9am  humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
#
#    pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  \
# 0       1007.7       1007.1       8.0       NaN     16.9     21.8       None
# 1       1010.6       1007.8       NaN       NaN     17.2     24.3       None
# 2       1007.6       1008.7       NaN       2.0     21.0     23.2       None
#
#    raintomorrow
# 0          None
# 1          None
# 2          None
#
# [3 rows x 23 columns]

# %% [markdown]
# #### 12.Create a new column called "difference", calculate the difference between maxtemp and mintemp columns for each row, and store the value in this new column.

# %%
df["difference"] = df["maxtemp"] - df["mintemp"]
diff = pd.DataFrame(df["difference"], columns=["difference"])
diff
# Out:
#         difference
# 0              9.5
# 1             17.7
# 2             12.8
# 3             18.8
# 4             14.8
# ...            ...
# 145455        20.6
# 145456        21.7
# 145457        21.5
# 145458        19.2
# 145459         NaN
#
# [145460 rows x 1 columns]

# %% [markdown]
# #### 13.Remove the evaporation and sunshine columns from the dataset permanently.

# %%
df.drop(["evaporation","sunshine"], axis=1)
df.head(3)
# Out:
#          date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 0  01/12/2008   Albury     13.4     22.9       0.6          NaN       NaN
# 1  02/12/2008   Albury      7.4     25.1       0.0          NaN       NaN
# 2  03/12/2008   Albury     12.9     25.7       0.0          NaN       NaN
#
#   windgustdir  windgustspeed winddir9am  ... humidity3pm  pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
#
#    pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  raintomorrow  \
# 0       1007.1       8.0       NaN     16.9     21.8       None          None
# 1       1007.8       NaN       NaN     17.2     24.3       None          None
# 2       1008.7       NaN       2.0     21.0     23.2       None          None
#
#    difference
# 0         9.5
# 1        17.7
# 2        12.8
#
# [3 rows x 24 columns]

# %% [markdown]
# #### 14.Find out the most rainy day for each city.

# %%
#a=df.groupby('location').rainfall.idxmax() max verinin oldugu yerdeki index
df_most_rainly=df.loc[df.groupby('location').rainfall.idxmax()].reset_index()[["location","date","rainfall"]]
df_most_rainly
# Out:
#             location        date  rainfall
# 0           Adelaide  14/02/2014      75.2
# 1             Albury  01/03/2012     104.2
# 2       AliceSprings  28/02/2010      62.0
# 3      BadgerysCreek  29/01/2013     116.0
# 4           Ballarat  05/02/2011      70.4
# 5            Bendigo  05/02/2011      66.4
# 6           Brisbane  02/05/2015     182.6
# 7             Cairns  12/01/2009     278.4
# 8           Canberra  03/12/2010      87.0
# 9              Cobar  16/02/2014      68.0
# 10      CoffsHarbour  05/06/2016     219.6
# 11          Dartmoor  14/01/2011      73.6
# 12            Darwin  16/02/2011     367.6
# 13         GoldCoast  29/04/2012     183.4
# 14            Hobart  14/01/2015      71.6
# 15         Katherine  27/12/2015     167.0
# 16        Launceston  29/01/2016      88.0
# 17         Melbourne  07/02/2011      82.2
# 18  MelbourneAirport  01/06/2013      75.8
# 19           Mildura  05/02/2011     155.0
# 20             Moree  26/11/2011     113.0
# 21      MountGambier  14/01/2011      84.6
# 22       MountGinini  04/03/2012     107.6
# 23              Nhil  12/06/2013      65.6
# 24         NorahHead  24/06/2013     126.4
# 25     NorfolkIsland  22/03/2016     156.8
# 26         Nuriootpa  08/12/2010      76.6
# 27        PearceRAAF  07/12/2011      62.4
# 28           Penrith  10/02/2012     115.4
# 29             Perth  10/02/2017     114.4
# 30      PerthAirport  11/07/2010      76.6
# 31          Portland  14/01/2011      72.0
# 32          Richmond  21/04/2015     113.4
# 33              Sale  07/12/2014      55.6
# 34        SalmonGums  02/03/2013      55.4
# 35            Sydney  21/04/2015     119.4
# 36     SydneyAirport  15/10/2014     106.8
# 37        Townsville  03/02/2009     236.8
# 38       Tuggeranong  09/12/2010      93.0
# 39             Uluru  26/12/2016      83.8
# 40        WaggaWagga  08/03/2010     110.8
# 41           Walpole  01/06/2012      93.2
# 42          Watsonia  01/06/2013      87.4
# 43       Williamtown  06/01/2016     225.0
# 44       Witchcliffe  15/07/2013      99.4
# 45        Wollongong  25/08/2015     192.0
# 46           Woomera  10/01/2015      66.4

# %% [markdown]
# ---

# %% [markdown]
# #### 15.Filter out all the data for the city 'Albury' and then sort according to maxtemp column.

# %%
df[df['location'].str.contains("Albury", na=False)].sort_values(
    "maxtemp", ascending=False)
# Out:
#             date location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# 68    07/02/2009   Albury     22.3     44.8       0.0          NaN       NaN
# 2904  10/02/2017   Albury     23.0     43.7       0.0          NaN       NaN
# 1783  16/01/2014   Albury     23.0     43.6       0.0          NaN       NaN
# 1435  05/01/2013   Albury     19.8     43.4       0.0          NaN       NaN
# 62    01/02/2009   Albury     28.0     43.1       0.0          NaN       NaN
# ...          ...      ...      ...      ...       ...          ...       ...
# 984   11/09/2011   Albury      NaN      NaN       NaN          NaN       NaN
# 985   12/09/2011   Albury      NaN      NaN       NaN          NaN       NaN
# 1529  07/05/2013   Albury      3.9      NaN       0.0          NaN       NaN
# 2031  21/09/2014   Albury      3.4      NaN       0.0          NaN       NaN
# 2032  22/09/2014   Albury      NaN      NaN       NaN          NaN       NaN
#
#      windgustdir  windgustspeed winddir9am  ... humidity3pm  pressure9am  \
# 68           NNW           59.0         SE  ...        11.0       1008.2
# 2904         WSW           44.0        SSE  ...        17.0       1009.9
# 1783           N           35.0          E  ...        12.0       1016.6
# 1435          NW           81.0          S  ...        17.0       1012.4
# 62            SW           83.0         SE  ...         9.0       1012.5
# ...          ...            ...        ...  ...         ...          ...
# 984          NaN            NaN        NaN  ...         NaN          NaN
# 985          NaN            NaN        NaN  ...         NaN          NaN
# 1529         NaN            NaN        NaN  ...         NaN       1028.6
# 2031         NaN            NaN        ESE  ...        43.0       1030.6
# 2032         NaN            NaN        NaN  ...         NaN          NaN
#
#       pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  raintoday  \
# 68         1003.8       NaN       NaN     29.6     43.4       None
# 2904       1006.1       NaN       NaN     28.2     42.4       None
# 1783       1012.2       NaN       NaN     31.8     41.7       None
# 1435       1009.8       NaN       1.0     30.7     42.4       None
# 62         1008.7       NaN       NaN     32.4     41.9       None
# ...           ...       ...       ...      ...      ...        ...
# 984           NaN       NaN       NaN      NaN      NaN       None
# 985           NaN       NaN       NaN      NaN      NaN       None
# 1529          NaN       NaN       NaN      9.8      NaN       None
# 2031       1027.5       NaN       NaN     12.2     18.6       None
# 2032          NaN       NaN       NaN      NaN      NaN       None
#
#       raintomorrow  difference
# 68            None        22.5
# 2904          None        20.7
# 1783          None        20.6
# 1435          None        23.6
# 62            None        15.1
# ...            ...         ...
# 984           None         NaN
# 985           None         NaN
# 1529          None         NaN
# 2031          None         NaN
# 2032          None         NaN
#
# [3040 rows x 24 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 16.Find out the NaN counts for each column.

# %%
df.isnull().sum(axis=0)
# Out:
# date                  0
# location              0
# mintemp            1485
# maxtemp            1261
# rainfall           3261
# evaporation       62790
# sunshine          69835
# windgustdir       10326
# windgustspeed     10263
# winddir9am        10566
# winddir3pm         4228
# windspeed9am       1767
# windspeed3pm       3062
# humidity9am        2654
# humidity3pm        4507
# pressure9am       15065
# pressure3pm       15028
# cloud9am          55888
# cloud3pm          59358
# temp9am            1767
# temp3pm            3609
# raintoday        145460
# raintomorrow     145460
# difference         1881
# dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ### 17.Remove the rows with NaN values in "windgustdir" column from the dataframe permanently.

# %%
df.dropna(subset=['windgustdir'], axis=0, inplace=True)
df
# Out:
#               date location  mintemp  maxtemp  rainfall  evaporation  \
# 0       01/12/2008   Albury     13.4     22.9       0.6          NaN
# 1       02/12/2008   Albury      7.4     25.1       0.0          NaN
# 2       03/12/2008   Albury     12.9     25.7       0.0          NaN
# 3       04/12/2008   Albury      9.2     28.0       0.0          NaN
# 4       05/12/2008   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145454  20/06/2017    Uluru      3.5     21.8       0.0          NaN
# 145455  21/06/2017    Uluru      2.8     23.4       0.0          NaN
# 145456  22/06/2017    Uluru      3.6     25.3       0.0          NaN
# 145457  23/06/2017    Uluru      5.4     26.9       0.0          NaN
# 145458  24/06/2017    Uluru      7.8     27.0       0.0          NaN
#
#         sunshine windgustdir  windgustspeed winddir9am  ... humidity3pm  \
# 0            NaN           W           44.0          W  ...        22.0
# 1            NaN         WNW           44.0        NNW  ...        25.0
# 2            NaN         WSW           46.0          W  ...        30.0
# 3            NaN          NE           24.0         SE  ...        16.0
# 4            NaN           W           41.0        ENE  ...        33.0
# ...          ...         ...            ...        ...  ...         ...
# 145454       NaN           E           31.0        ESE  ...        27.0
# 145455       NaN           E           31.0         SE  ...        24.0
# 145456       NaN         NNW           22.0         SE  ...        21.0
# 145457       NaN           N           37.0         SE  ...        24.0
# 145458       NaN          SE           28.0        SSE  ...        24.0
#
#         pressure9am  pressure3pm  cloud9am  cloud3pm  temp9am  temp3pm  \
# 0            1007.7       1007.1       8.0       NaN     16.9     21.8
# 1            1010.6       1007.8       NaN       NaN     17.2     24.3
# 2            1007.6       1008.7       NaN       2.0     21.0     23.2
# 3            1017.6       1012.8       NaN       NaN     18.1     26.5
# 4            1010.8       1006.0       7.0       8.0     17.8     29.7
# ...             ...          ...       ...       ...      ...      ...
# 145454       1024.7       1021.2       NaN       NaN      9.4     20.9
# 145455       1024.6       1020.3       NaN       NaN     10.1     22.4
# 145456       1023.5       1019.1       NaN       NaN     10.9     24.5
# 145457       1021.0       1016.8       NaN       NaN     12.5     26.1
# 145458       1019.4       1016.5       3.0       2.0     15.1     26.0
#
#         raintoday  raintomorrow  difference
# 0            None          None         9.5
# 1            None          None        17.7
# 2            None          None        12.8
# 3            None          None        18.8
# 4            None          None        14.8
# ...           ...           ...         ...
# 145454       None          None        18.3
# 145455       None          None        20.6
# 145456       None          None        21.7
# 145457       None          None        21.5
# 145458       None          None        19.2
#
# [135134 rows x 24 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 18. Create a new dataframe, use "Location" column as the index of the dataframe, display the min, max, and median values of "evaporation" and "sunshine" columns in this dataframe.

# %%
df2 = df.copy()
a   = df2.groupby("location")[["evaporation", "sunshine"]]
dfmin = a.min()
dfmin
# Out:
#                   evaporation  sunshine
# location
# Adelaide                  0.0       0.0
# Albury                    NaN       NaN
# AliceSprings              0.0       0.0
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                   0.0       NaN
# Brisbane                  0.0       0.0
# Cairns                    0.2       0.0
# Canberra                  0.0       0.0
# Cobar                     0.0       0.0
# CoffsHarbour              0.0       0.0
# Dartmoor                  0.0       0.0
# Darwin                    0.2       0.0
# GoldCoast                 NaN       NaN
# Hobart                    0.0       0.0
# Katherine                 0.0       NaN
# Launceston                0.0       NaN
# Melbourne                 0.0       0.0
# MelbourneAirport          0.0       0.0
# Mildura                   0.0       0.0
# Moree                     0.2       0.0
# MountGambier              0.0       0.0
# MountGinini               NaN       NaN
# Nhil                      NaN       NaN
# NorahHead                 NaN       NaN
# NorfolkIsland             0.0       0.0
# Nuriootpa                 0.0       0.0
# PearceRAAF                NaN       0.0
# Penrith                   NaN       NaN
# Perth                     0.0       0.0
# PerthAirport              0.0       0.0
# Portland                  0.0       0.0
# Richmond                  0.0       NaN
# Sale                      0.0       0.0
# SalmonGums                NaN       NaN
# Sydney                    0.0       0.0
# SydneyAirport             0.0       0.0
# Townsville                0.4       0.0
# Tuggeranong               NaN       NaN
# Uluru                     NaN       NaN
# WaggaWagga                0.0       0.0
# Walpole                   NaN       NaN
# Watsonia                  0.0       0.0
# Williamtown               0.0       0.0
# Witchcliffe               NaN       NaN
# Wollongong                NaN       NaN
# Woomera                   0.0       0.0

# %%
dfmax = a.max()
dfmax
# Out:
#                   evaporation  sunshine
# location
# Adelaide                 43.4      13.9
# Albury                    NaN       NaN
# AliceSprings             50.2      13.4
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                  15.4       NaN
# Brisbane                 44.0      13.5
# Cairns                   44.4      12.8
# Canberra                 17.2      13.6
# Cobar                    86.2      13.7
# CoffsHarbour             19.8      13.8
# Dartmoor                 16.4      14.3
# Darwin                   19.2      12.3
# GoldCoast                 NaN       NaN
# Hobart                   20.2      14.2
# Katherine                31.0       NaN
# Launceston               30.4       NaN
# Melbourne                23.8      13.9
# MelbourneAirport         23.8      13.9
# Mildura                  23.2      14.5
# Moree                    65.4      14.0
# MountGambier             16.4      14.3
# MountGinini               NaN       NaN
# Nhil                      NaN       NaN
# NorahHead                 NaN       NaN
# NorfolkIsland            74.8      13.3
# Nuriootpa                42.6      14.3
# PearceRAAF                NaN      13.9
# Penrith                   NaN       NaN
# Perth                    17.0      13.9
# PerthAirport             17.0      13.9
# Portland                 16.4      14.3
# Richmond                 37.2       NaN
# Sale                     16.0      13.9
# SalmonGums                NaN       NaN
# Sydney                   18.4      13.6
# SydneyAirport            18.4      13.6
# Townsville               30.2      12.8
# Tuggeranong               NaN       NaN
# Uluru                     NaN       NaN
# WaggaWagga               39.4      14.1
# Walpole                   NaN       NaN
# Watsonia                 23.8      13.9
# Williamtown              64.4      13.7
# Witchcliffe               NaN       NaN
# Wollongong                NaN       NaN
# Woomera                  82.4      14.2

# %%
dfmedian = a.median()
dfmedian
# Out:
#                   evaporation  sunshine
# location
# Adelaide                  4.2       8.4
# Albury                    NaN       NaN
# AliceSprings              8.2      10.6
# BadgerysCreek             NaN       NaN
# Ballarat                  NaN       NaN
# Bendigo                   3.1       NaN
# Brisbane                  5.2       9.4
# Cairns                    6.0       8.6
# Canberra                  3.4       8.1
# Cobar                     5.6       9.9
# CoffsHarbour              3.6       8.5
# Dartmoor                  2.6       6.4
# Darwin                    6.4      10.0
# GoldCoast                 NaN       NaN
# Hobart                    3.2       6.9
# Katherine                 7.2       NaN
# Launceston                5.2       NaN
# Melbourne                 4.0       6.5
# MelbourneAirport          4.0       6.5
# Mildura                   5.2       9.1
# Moree                     6.4      10.1
# MountGambier              2.8       6.5
# MountGinini               NaN       NaN
# Nhil                      NaN       NaN
# NorahHead                 NaN       NaN
# NorfolkIsland             4.4       7.8
# Nuriootpa                 4.0       8.2
# PearceRAAF                NaN       9.4
# Penrith                   NaN       NaN
# Perth                     4.8       9.4
# PerthAirport              5.0       9.4
# Portland                  2.8       6.5
# Richmond                  4.0       NaN
# Sale                      3.4       7.0
# SalmonGums                NaN       NaN
# Sydney                    5.0       8.2
# SydneyAirport             4.9       8.2
# Townsville                7.0      10.0
# Tuggeranong               NaN       NaN
# Uluru                     NaN       NaN
# WaggaWagga                4.0       9.1
# Walpole                   NaN       NaN
# Watsonia                  4.0       6.5
# Williamtown               5.2       8.1
# Witchcliffe               NaN       NaN
# Wollongong                NaN       NaN
# Woomera                   8.6       9.9

# %% [markdown]
# ---

# %% [markdown]
# ### 19.Find out the hottest day of "Perth". Example output: Timestamp('2015-01-05 00:00:00')

# %%
#a = df[df['location']=="Perth"][["location","date","maxtemp"]].sort_values("maxtemp", ascending=False)
# a.iloc[0]
a = df[df['location'].str.contains("Perth", na=False)].sort_values(
    "maxtemp", ascending=False)
a.iloc[0][["location", "date", "maxtemp"]]
# Out:
# location         Perth
# date        05/01/2015
# maxtemp           44.4
# Name: 122928, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ### 20.Group your dataframe by location and find out the averages of all numeric values.

# %%
df.groupby("location").mean()
# Out:
#                     mintemp    maxtemp  rainfall  evaporation  sunshine  \
# location
# Adelaide          12.571487  22.891254  1.576076     5.757117  7.742417
# Albury             9.518588  22.629555  1.904552          NaN       NaN
# AliceSprings      13.155254  29.281325  0.869484     9.042405  9.592820
# BadgerysCreek     11.135741  24.014949  2.215406          NaN       NaN
# Ballarat           7.348670  18.267930  1.706369          NaN       NaN
# Bendigo            8.611841  21.625609  1.631586     3.835616       NaN
# Brisbane          16.414204  26.436043  3.119424     5.406064  8.069265
# Cairns            21.225099  29.559550  5.701852     6.244197  7.577948
# Canberra           6.670100  20.731579  1.745920     4.134289  7.419064
# Cobar             13.131412  25.853488  1.132655     6.751995  8.693236
# CoffsHarbour      14.522998  23.971493  4.990985     3.912857  7.353320
# Dartmoor           8.620518  19.696769  2.150272     3.354226  6.419215
# Darwin            23.190022  32.538259  5.076454     6.315255  8.522194
# GoldCoast         17.287324  25.713189  3.737301          NaN       NaN
# Hobart             9.080883  17.858517  1.604739     3.599146  6.574842
# Katherine         20.546272  34.915762  3.239856     7.325926       NaN
# Launceston         7.858822  18.983062  2.016483     6.190714       NaN
# Melbourne         11.770359  20.760489  1.874019     4.642884  6.387980
# MelbourneAirport   9.962558  20.478958  1.456045     4.634437  6.378750
# Mildura           10.738782  24.848202  0.945370     5.938816  8.468361
# Moree             12.909625  26.975060  1.612936     7.639713  8.917212
# MountGambier       8.820797  19.818882  2.078296     3.425587  6.505339
